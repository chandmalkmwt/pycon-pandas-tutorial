# %% [markdown]
# <a href="https://colab.research.google.com/github/chandmalkmwt/pycon-pandas-tutorial/blob/master/WnCC_week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Public link
#
# after explanation mark what you right is not run by python but executed by system environment

# %%
# !wget https://github.com/datasciencedojo/datasets/blob/master/titanic.csv
# Out:
# --2022-05-17 08:13:00--  https://github.com/datasciencedojo/datasets/blob/master/titanic.csv
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘titanic.csv’
#
# titanic.csv             [ <=>                ] 558.49K  --.-KB/s    in 0.07s
#
# 2022-05-17 08:13:00 (8.21 MB/s) - ‘titanic.csv’ saved [571890]

# %%
# !ls  #for see what files are already exist
# Out:
# sample_data  titanic.csv

# %% [markdown]
# #Google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Github link

# %%
# !git clone https://github.com/ankit25587/Natural-Language-Processing-with-Python.git
# Out:
# Cloning into 'Natural-Language-Processing-with-Python'...
# remote: Enumerating objects: 30, done.
# remote: Total 30 (delta 0), reused 0 (delta 0), pack-reused 30
# Unpacking objects: 100% (30/30), done.

# %% [markdown]
# #Local Drive

# %%
import pandas as pd
pd.read_csv(HousingData.csv').head()

# %% [markdown]
# #This *is* **heading**
#
#
#
# ```
# # This is formatted as code
# for item in list:
#     print(item)
# ```

# %% [markdown]
# ![1646329941006.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# [Google Search](https://www.google.com)

# %% [markdown]
# $ ax^2+bx+c=0$

# %% [markdown]
# $$x1=\frac{-b+\sqrt{b^2-4ac}}{2a}$$

# %% [markdown]
# ##Save
